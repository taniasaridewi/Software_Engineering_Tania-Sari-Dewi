# %%
#Luas lingkaran
phi = 3.14
r = float(input("Input jari-jari lingkaran: "))
luas = phi*r*r
print("Luas lingkaran adalah : {}".format(luas))
# Out:
# Input jari-jari lingkaran: 20
# Luas lingkaran adalah : 1256.0
