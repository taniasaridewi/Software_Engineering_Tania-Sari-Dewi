# %%
#comment
a = 10 #integer
b = 3.14 #float
c = "T" #String
d = "Tania"
e = "SoftEng"
f = True #boolean
g = False #boolean
h = [] #List
i = [1,2,3] #List
j = {} #Dictionary
k = () #Tuple

# %%
List1 =[0, 1, "tania", True, ['tania', 8]]

# %%
#Print
print(e)
print(2+5*3)
print('hello world')
# Out:
# SoftEng
# 17
# hello world

# %%
nama = 'Tania'
umur = 20
tinggal = "Cikarang"

# %%
nama = input()
# Out:
# tania

# %%
print("Hai nama ku adalah " +nama) #concatination
print("Hai nama ku adalah {}".format(nama))
print("Hai nama ku adalah {}".format("Tania"))
# Out:
# Hai nama ku adalah tania
# Hai nama ku adalah tania
# Hai nama ku adalah Tania

# %%
print("Hai nama ku adalah {}, umurku {}".format(nama, umur))
print("Hai nama ku adalah " +nama+ ", umurku "+str(umur))
print("Hai nama ku adalah {}, umurku {}, tinggal di {}".format(nama, umur, tinggal))
# Out:
# Hai nama ku adalah Tania, umurku 20
# Hai nama ku adalah Tania, umurku 20
# Hai nama ku adalah Tania, umurku 20, tinggal di Cikarang

# %%
import.math

a = 10 
b = 10
#if else
#conditional statement
a == b #jika a sama dengan b
a != b #jika a tidak sama dengan b
a < b
a <= b
a > b
a >= b
True and True
False or True

#operator
a + b
a - b
a * b
a / b # 10 / 10 = 1.0 > float division
a // b # 10 // 10 = 1 > int division
a ** b # 10 ^ 10 = 100
a % b 
a ** (1/2) #akar variable a, dimana a = 10
math.sqrt(a) #akar variable a
math.sin(a)
math.cos(a)
math.tan(a)
math.tanh(a)
math.sinh(a)
math.cosh(a)
math.log(a)
# Out:
#   File "<ipython-input-2-02346a287092>", line 1
#     import.math
#           ^
# SyntaxError: invalid syntax

# %%
if a == 10:
  print ('a sama dengan 10')
elif a > 10:
  print ('a lebih besar dari 10')
else:
  print('a kurang dari 10')
print('ini diluar if')
# Out:
# a sama dengan 10
# ini diluar if
